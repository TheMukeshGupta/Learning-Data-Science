# %% [markdown]
# # Data Manipulation with Pandas
#
# Pandas is the most widely used library of python for data science. It is incredibly helpful in manipulating the data so that you can derive better insights and build great machine learning models.
#
# In this notebook, we will have a look at some of the intermediate concepts of working with pandas.

# %% [markdown]
# 1. Importing Pandas
# 2. Read CSV File
# 3. Read Head Data or top rows data

# %%
# Import Pandas

import pandas as pd

# %%
# Reading CSV files

df = pd.read_csv("D:\\Python Projects\\BigMartSales\\train_v9rqX0R.csv")

# %%
# printing CSV top 5 rows data

df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ## Working With Columns
#
# - Print All Columns Name of Dataframe
# - Select Column by column name
# - Select Multiple Columns by name
# - Select Columns by Index

# %%
# Print All column Name

df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# Selecting a single column by name

df['Item_Type']
# Out:
# 0                       Dairy
# 1                 Soft Drinks
# 2                        Meat
# 3       Fruits and Vegetables
# 4                   Household
#                 ...
# 8518              Snack Foods
# 8519             Baking Goods
# 8520       Health and Hygiene
# 8521              Snack Foods
# 8522              Soft Drinks
# Name: Item_Type, Length: 8523, dtype: object

# %%
# Selecting Multiple columns by name

df[['Item_Fat_Content','Item_Type']]
# Out:
#      Item_Fat_Content              Item_Type
# 0             Low Fat                  Dairy
# 1             Regular            Soft Drinks
# 2             Low Fat                   Meat
# 3             Regular  Fruits and Vegetables
# 4             Low Fat              Household
# ...               ...                    ...
# 8518          Low Fat            Snack Foods
# 8519          Regular           Baking Goods
# 8520          Low Fat     Health and Hygiene
# 8521          Regular            Snack Foods
# 8522          Low Fat            Soft Drinks
#
# [8523 rows x 2 columns]

# %%
# Selecting rows by their Index

df.iloc[:5] # Returns upto 5 rows and all columns
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Selecting columns by their Index

df.iloc[:,:2]  # Returns all rows and 2 columns data
# Out:
#      Item_Identifier  Item_Weight
# 0              FDA15        9.300
# 1              DRC01        5.920
# 2              FDN15       17.500
# 3              FDX07       19.200
# 4              NCD19        8.930
# ...              ...          ...
# 8518           FDF22        6.865
# 8519           FDS36        8.380
# 8520           NCJ29       10.600
# 8521           FDN46        7.210
# 8522           DRG01       14.800
#
# [8523 rows x 2 columns]

# %%
# Select Rows on Some Conditions

# select all items are low in fat

df[df['Item_Fat_Content']=='Low Fat']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 7              FDP10          NaN          Low Fat         0.127470
# 10             FDY07       11.800          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8518           FDF22        6.865          Low Fat         0.056783
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# # data Cleaning

# %%
# Describe The Dataframe

df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# Dtypes of dataframe
# Returns Dtype of Each Variable

df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Count values of each columns or row
# axis =0 for columns
# axis = 1 for rows
# default axis = 0

df.count()
# Out:
# Item_Identifier              8523
# Item_Weight                  7060
# Item_Fat_Content             8523
# Item_Visibility              8523
# Item_Type                    8523
# Item_MRP                     8523
# Outlet_Identifier            8523
# Outlet_Establishment_Year    8523
# Outlet_Size                  6113
# Outlet_Location_Type         8523
# Outlet_Type                  8523
# Item_Outlet_Sales            8523
# dtype: int64

# %%
# Print sum of Null values in columns
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Fill Null values

df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)
df['Outlet_Size'].fillna(method='ffill',inplace=True)

# %%
#Checking Data Filled or not

df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#checking Coloumn values count 

df.groupby('Item_Fat_Content').groups
# Out:
# {'LF': Int64Index([  45,   65,  121,  175,  207,  210,  219,  238,  389,  415,
#              ...
#              8241, 8259, 8273, 8340, 8351, 8367, 8379, 8391, 8443, 8467],
#             dtype='int64', length=316),
#  'Low Fat': Int64Index([   0,    2,    4,    7,   10,   14,   16,   18,   19,   22,
#              ...
#              8504, 8506, 8509, 8511, 8512, 8515, 8516, 8518, 8520, 8522],
#             dtype='int64', length=5089),
#  'Regular': Int64Index([   1,    3,    5,    6,    8,    9,   11,   12,   13,   15,
#              ...
#              8496, 8501, 8505, 8507, 8508, 8510, 8513, 8514, 8519, 8521],
#             dtype='int64', length=2889),
#  'low fat': Int64Index([  27,   74,   82,  108,  111,  292,  417,  496,  600,  766,
#              ...
#              7718, 7792, 7886, 7890, 7903, 7925, 8068, 8295, 8380, 8404],
#             dtype='int64', length=112),
#  'reg': Int64Index([  81,  151,  199,  339,  396,  489,  615,  727,  753,  838,
#              ...
# ...

# %%
#Replacing string

df['Item_Fat_Content'].replace({'LF':'Low Fat','low fat':'Low Fat','reg':'Regular'},inplace=True)
df.groupby('Item_Fat_Content').groups
# Out:
# {'Low Fat': Int64Index([   0,    2,    4,    7,   10,   14,   16,   18,   19,   22,
#              ...
#              8504, 8506, 8509, 8511, 8512, 8515, 8516, 8518, 8520, 8522],
#             dtype='int64', length=5517),
#  'Regular': Int64Index([   1,    3,    5,    6,    8,    9,   11,   12,   13,   15,
#              ...
#              8501, 8505, 8507, 8508, 8510, 8513, 8514, 8517, 8519, 8521],
#             dtype='int64', length=3006)}

# %%
#Sum of all Item_MRP Values
df['Item_MRP'].sum()
# Out:
# 1201681.4808

# %%
 #Mean of All Item_MRP Values
df['Item_MRP'].mean()
# Out:
# 140.9927819781768

# %%
# Minimum Of Item_MRP Values

df['Item_MRP'].min()
# Out:
# 31.29

# %%
# Maximum Of Item_MRP Values
df['Item_MRP'].max()
# Out:
# 266.8884

# %%
# Standard Daviation Of Item_MRP Values
df['Item_MRP'].std()
# Out:
# 62.27506651219039

# %%
# Simple Variance Of Item_MRP Values
df['Item_MRP'].var()
# Out:
# 3878.1839090977373

# %%
# Meadian Of Item_MRP Values
df['Item_MRP'].median()
# Out:
# 143.0128

# %%
# Correlation Matrix Of Values
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.012049  0.024756
# Item_Visibility              -0.012049         1.000000 -0.001315
# Item_MRP                      0.024756        -0.001315  1.000000
# Outlet_Establishment_Year    -0.008301        -0.074834  0.005020
# Item_Outlet_Sales             0.011550        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008301           0.011550
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
# Covariance Matrix Of Values

df.cov()
# Out:
#                            Item_Weight  Item_Visibility      Item_MRP  \
# Item_Weight                  17.860122        -0.002627      6.515364
# Item_Visibility              -0.002627         0.002662     -0.004225
# Item_MRP                      6.515364        -0.004225   3878.183909
# Outlet_Establishment_Year    -0.293684        -0.032325      2.617143
# Item_Outlet_Sales            83.297203       -11.325611  60317.485612
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.293684       8.329720e+01
# Item_Visibility                            -0.032325      -1.132561e+01
# Item_MRP                                    2.617143       6.031749e+04
# Outlet_Establishment_Year                  70.086372      -7.019621e+02
# Item_Outlet_Sales                        -701.962133       2.912141e+06

# %%
# Showing non null count of each variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# # Plotting with Pandas
#
# 1. Boxplot
# 2. Histogram

# %%
#Plotting Boxplot
# Compare Outlet_Typet by Item_Outlet_Sales 

df.boxplot(by="Outlet_Type",column="Item_Outlet_Sales")

# %%
#Plotting Histogram
# Compare Outlet_Typet by Item_Outlet_Sales 

df.hist(by="Outlet_Type",column="Item_Outlet_Sales")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A246E1B788>,
# ...
#       dtype=object)

# %% [markdown]
# ## Sorting Dataframe
#
# 1. sort_values() - Sort data By Column Wise
# 2. sort_index() - Sort Data By Row wise

# %%
# Sorting DataFrame 

df.sort_values(by="Outlet_Type")[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3993           FDI15    12.857645          Low Fat         0.247490
# 3055           FDZ12     9.170000          Low Fat         0.172365
# 5057           NCJ19    18.600000          Low Fat         0.197809
# 1291           FDY24     4.880000          Regular         0.223440
# 5050           NCA30    19.000000          Low Fat         0.216478
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 3993         Dairy  263.1884            OUT019                       1985
# 3055  Baking Goods  144.8470            OUT010                       1998
# 5057        Others   55.6588            OUT010                       1998
# 1291  Baking Goods   52.2298            OUT010                       1998
# 5050     Household  190.1872            OUT010                       1998
#
#      Outlet_Size Outlet_Location_Type    Outlet_Type  Item_Outlet_Sales
# ...

# %%
# Sort Dataframe by multiple column variables

df.sort_values(by=['Item_Identifier','Outlet_Establishment_Year'])[:10]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1245           DRA12    11.600000          Low Fat         0.040912
# 8043           DRA12    11.600000          Low Fat         0.068535
# 1197           DRA12    11.600000          Low Fat         0.000000
# 1693           DRA12    11.600000          Low Fat         0.000000
# 118            DRA12    11.600000          Low Fat         0.041178
# 7467           DRA12    11.600000          Low Fat         0.041113
# 2879           DRA24    12.857645          Regular         0.069909
# 4416           DRA24    12.857645          Regular         0.039735
# 8195           DRA24    19.350000          Regular         0.039895
# 4130           DRA24    19.350000          Regular         0.066832
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 1245  Soft Drinks  142.3154            OUT013                       1987
# ...

# %% [markdown]
# ### Sort Dataframe by multiple column variables
# ### Prefrence of sorting depends on first Column

# %%
df.sort_values(by=['Outlet_Establishment_Year','Item_Identifier'],inplace=True)
df[:10]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2879           DRA24    12.857645          Regular         0.069909
# 4416           DRA24    12.857645          Regular         0.039735
# 6057           DRA59    12.857645          Regular         0.127308
# 6179           DRA59    12.857645          Regular         0.223985
# 3733           DRB01    12.857645          Low Fat         0.081841
# 2533           DRB25    12.857645          Low Fat         0.069123
# 458            DRB48    12.857645          Regular         0.024733
# 2927           DRC01    12.857645          Regular         0.019107
# 1708           DRC25    12.857645          Low Fat         0.079440
# 6719           DRC25    12.857645          Low Fat         0.000000
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2879  Soft Drinks  163.2868            OUT019                       1985
# ...

# %%
# Sort Dataframe by row index
df.sort_index(inplace=True)
df[:10]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15     9.300000          Low Fat         0.016047
# 1           DRC01     5.920000          Regular         0.019278
# 2           FDN15    17.500000          Low Fat         0.016760
# 3           FDX07    19.200000          Regular         0.000000
# 4           NCD19     8.930000          Low Fat         0.000000
# 5           FDP36    10.395000          Regular         0.000000
# 6           FDO10    13.650000          Regular         0.012741
# 7           FDP10    12.857645          Low Fat         0.127470
# 8           FDH17    16.200000          Regular         0.016687
# 9           FDU28    19.200000          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
# get Unique Variable of column

df['Outlet_Size'].unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
# Create New Column of Outlet_Establishment_Years Via Defining Bin Edges

df['Outlet_Establishment_Year_bins']=pd.cut(x=df['Outlet_Establishment_Year'], bins=[1980,1989,1999,2009])

# %%
# Verify Bins

df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# aggregations in Pandas namely the following functions:
#
# 1. Crosstab
#
# 2. Groupby
#
# 3. Pivot Table

# %%
# Get Mean price by Item Type 

mean_price = df.groupby('Item_Type')
mean_price.first()
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Baking Goods                    FDP36    10.395000          Regular
# Breads                          FDO23    17.850000          Low Fat
# Breakfast                       FDP49     9.000000          Regular
# Canned                          FDC14    12.857645          Regular
# Dairy                           FDA15     9.300000          Low Fat
# Frozen Foods                    FDH17    16.200000          Regular
# Fruits and Vegetables           FDX07    19.200000          Regular
# Hard Drinks                     DRI11    12.857645          Low Fat
# Health and Hygiene              NCB42    11.800000          Low Fat
# Household                       NCD19     8.930000          Low Fat
# Meat                            FDN15    17.500000          Low Fat
# Others                          NCN07    18.500000          Low Fat
# Seafood                         FDG33    12.857645          Regular
# ...

# %%
# Mean Price By item Type
mean_price.Item_MRP.mean()
# Out:
# Item_Type
# Baking Goods             126.380766
# Breads                   140.952669
# Breakfast                141.788151
# Canned                   139.763832
# Dairy                    148.499208
# Frozen Foods             138.503366
# Fruits and Vegetables    144.581235
# Hard Drinks              137.077928
# Health and Hygiene       130.818921
# Household                149.424753
# Meat                     139.882032
# Others                   132.851430
# Seafood                  141.841719
# Snack Foods              146.194934
# Soft Drinks              131.492506
# Starchy Foods            147.838023
# Name: Item_MRP, dtype: float64

# %%
#Use Group by With Multiple Variables
mul_grp = df.groupby(['Item_Type','Item_Fat_Content'])
mul_grp.first()
# Out:
#                                        Item_Identifier  Item_Weight  \
# Item_Type             Item_Fat_Content
# Baking Goods          Low Fat                    FDC37    12.857645
#                       Regular                    FDP36    10.395000
# Breads                Low Fat                    FDO23    17.850000
#                       Regular                    FDV11     9.100000
# Breakfast             Low Fat                    FDN13    18.600000
#                       Regular                    FDP49     9.000000
# Canned                Low Fat                    FDC02    21.350000
#                       Regular                    FDC14    12.857645
# Dairy                 Low Fat                    FDA15     9.300000
#                       Regular                    FDA03    18.500000
# Frozen Foods          Low Fat                    FDM40    10.195000
#                       Regular                    FDH17    16.200000
# ...

# %%
# How are Outlet size distributed based on the City type?

# Generate crosstab of Outlet_Size and Outlet_Location_Type

pd.crosstab(df['Outlet_Size'],df['Outlet_Location_Type'],margins=True)
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3   All
# Outlet_Size
# High                       0     279    1011  1290
# Medium                   930     859    2123  3912
# Small                   1458    1647     216  3321
# All                     2388    2785    3350  8523

# %%
# How are the sales changing per year?

# Create Pivottable
# data: DataFrame
#Index: Column name data need to be group
# Values(Optional): Column need to aggregate, if doesn't proided all numeric column will be aggregate
# Returns Mean Value

pd.pivot_table(df,index=['Outlet_Establishment_Year'],values=['Item_Outlet_Sales'])
# Out:
#                            Item_Outlet_Sales
# Outlet_Establishment_Year
# 1985                             2483.677474
# 1987                             2298.995256
# 1997                             2277.844267
# 1998                              339.351662
# 1999                             2348.354635
# 2002                             2192.384798
# 2004                             2438.841866
# 2007                             2340.675263
# 2009                             1995.498739

# %%
# Pivot Table with Multiple Columns

pd.pivot_table(df,index=['Outlet_Establishment_Year','Outlet_Size'],values=['Item_Outlet_Sales'])
# Out:
#                                        Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Size
# 1985                      Medium             3694.038558
#                           Small               340.329723
# 1987                      High               2298.995256
# 1997                      Small              2277.844267
# 1998                      High                365.397782
#                           Medium              347.427244
#                           Small               320.104927
# 1999                      Medium             2348.354635
# 2002                      High               2194.348232
#                           Medium             2251.858517
#                           Small              2109.268566
# 2004                      Small              2438.841866
# 2007                      High               2444.469794
#                           Medium             2320.907935
#                           Small              2325.411175
# ...

# %%
# Multiple Aggreagtion Functions
import numpy as np
pd.pivot_table(df,index=['Outlet_Establishment_Year','Outlet_Size'],values=['Item_Outlet_Sales'],aggfunc=[max,min,np.mean,np.std])
# Out:
#                                                     max               min  \
#                                       Item_Outlet_Sales Item_Outlet_Sales
# Outlet_Establishment_Year Outlet_Size
# 1985                      Medium             13086.9648          241.6854
#                           Small               1482.0708           33.9558
# 1987                      High               10256.6490           73.2380
# 1997                      Small               9779.9362          101.8674
# 1998                      High                1342.2528           49.2692
#                           Medium              1575.2828           39.9480
#                           Small               1775.6886           33.2900
# 1999                      Medium              7646.0472          111.8544
# 2002                      High                8323.8316          154.4656
#                           Medium              8604.7992           99.8700
# ...

# %% [markdown]
#  Merging dataframes
#
# - Joining and merging DataFrames is the core process to start with data analysis and machine learning tasks.
# - It is one of the toolkits which every Data Analyst or Data Scientist should master because in almost all the cases data comes from multiple source and files.
# - Pandas has two useful functions for merging dataframes:
#     - **concat()**
#     - **merge()**
#
# #### Creating dummy data

# %%
# create dummy data
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3'],
                     'C': ['C0', 'C1', 'C2', 'C3'],
                     'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])
 

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                     'B': ['B4', 'B5', 'B6', 'B7'],
                     'C': ['C4', 'C5', 'C6', 'C7'],
                     'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])
 

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                     'B': ['B8', 'B9', 'B10', 'B11'],
                     'C': ['C8', 'C9', 'C10', 'C11'],
                     'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %%
#concat() for combining dataframes

result = pd.concat([df1, df2, df3])
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
# combine dataframes & abel the DataFrames
# keys specifying the label names of the DataFrames in a list
result = pd.concat([df1, df2, df3], keys=['x', 'y', 'z'])
result
# Out:
#         A    B    C    D
# x 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %%
# retrieve the data of DataFrame df2 which had the label y by using the loc method

result.loc['y']
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %% [markdown]
# - When gluing together multiple DataFrames, you have a choice of how to handle the other axes (other than the one being concatenated). This can be done in the following three ways:
#
#     - Take the union of them all, `join='outer'`. This is the default option as it results in zero information loss.
#     - Take the intersection, `join='inner'`.
#     - Use a specific index, as passed to the `join_axes` argument.
#
# - Here is an example of each of these methods. First, the default `join='outer'` behavior:

# %%
# Create Dummy DataFrame df4

df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                        'D': ['D2', 'D3', 'D6', 'D7'],
                        'F': ['F2', 'F3', 'F6', 'F7']},
                       index=[2, 3, 6, 7])
print("df1:",df1,"df4:",df4,sep="\n")
# Out:
# df1:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# df4:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
# Here is an example of each of these methods. First, the default join='outer' behavior:
result = pd.concat([df1, df4], axis=1, sort=False)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
# Here is the same thing with join='inner'
result = pd.concat([df1, df4], axis=1, join='inner')
result
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# ### b. merge() for combining dataframes using SQL like joins
#
# - Another ubiquitous operation related to DataFrames is the merging operation.
# - Two DataFrames might hold different kinds of information about the same entity and linked by some common feature/column.
# - We can use **merge()** to combine such dataframes in pandas.
#
# #### Creating dummy data

# %%
# create dummy data
df_a = pd.DataFrame({
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']})

df_b = pd.DataFrame({
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']})

df_c = pd.DataFrame({
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]})

# %%
# combine df_a with df_c based on the subject_id column

res = pd.merge(df_a,df_c,on='subject_id')
res
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %% [markdown]
# # Merge With 'Outer Join'
#  Full outer join produces the set of all records in Table A and Table B,
# with matching records from both sides where available.
# If there is no match, the missing side will contain null.”

# %%
pd.merge(df_a, df_b, on='subject_id', how='outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# # Merge with 'inner join'
# "Inner join produces only the set of records that match in both Table A and Table B."

# %%
pd.merge(df_a,df_b,on='subject_id',how='inner')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %% [markdown]
# # Merge with right join
# “Right outer join produces a complete set of records from Table B, with the matching records (where available) in Table A. If there is no match, the left side will contain null.”

# %%
pd.merge(df_a,df_b,on='subject_id',how='right')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black
# 2          6          NaN         NaN         Bran     Balwner
# 3          7          NaN         NaN        Bryce       Brice
# 4          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# # Merge with left join
# “Left outer join produces a complete set of records from Table A, with the matching records (where available) in Table B. If there is no match, the right side will contain null.”

# %%
pd.merge(df_a,df_b,on='subject_id',how='left')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
